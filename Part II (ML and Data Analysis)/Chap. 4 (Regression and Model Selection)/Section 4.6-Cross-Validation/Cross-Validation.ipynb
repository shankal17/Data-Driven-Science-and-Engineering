# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from sklearn import linear_model
from mpl_toolkits.mplot3d import Axes3D 

rcParams.update({'font.size': 18})
plt.rcParams['figure.figsize'] = [12, 12]

# %%
n = 100
L = 4
x = np.linspace(0, L, n)
f = np.power(x, 2) # parabola with 100 data points

M = 21 # Polynomial degree
phi = np.zeros((n, M))
for j in range(M):
    phi[:, j] = np.power(x, j) # build matrix A
    
trials = np.array([2, 10, 100])

fig,axs = plt.subplots(3, 3)

for j in range(len(trials)):
    trial = trials[j]
    E1 = np.zeros(trial)
    E2 = np.zeros(trial)
    E3 = np.zeros(trial)
    
    A1 = np.zeros((M, trial))
    A2 = np.zeros((M, trial))
    A3 = np.zeros((M, trial))

    
    for jj in range(trial):
        f = np.power(x, 2) + 0.2*np.random.randn(n)
        a1 = np.linalg.pinv(np.copy(phi)) @ np.copy(f)
        f1 = phi @ a1
        E1[jj] = np.linalg.norm(f-f1, ord=2)/np.linalg.norm(f, ord=2)
        
        a2 = np.linalg.lstsq(np.copy(phi), np.copy(f), rcond=None)[0]
        f2 = phi @ a2
        E2[jj] = np.linalg.norm(f-f2, ord=2)/np.linalg.norm(f, ord=2)
        
#         regr3 = linear_model.ElasticNet(alpha=1.0, copy_X=True, l1_ratio=0.1, max_iter=10**5,random_state=0)
        regr3 = linear_model.Lasso(alpha=1)
        regr3.fit(phi, f)  
        a3 = regr3.coef_
        f3 = phi @ a3
        E3[jj] = np.linalg.norm(f-f3, ord=2)/np.linalg.norm(f, ord=2)
        
        A1[:,jj] = a1
        A2[:,jj] = a2
        A3[:,jj] = a3
        
    A1m = np.mean(A1, axis=1)
    A2m = np.mean(A2, axis=1)
    A3m = np.mean(A3, axis=1)
    
    Err = np.column_stack((E1, E2, E3))
    
    axs[0,j].bar(range(M), A1m)
    axs[1,j].bar(range(M), A2m)
    axs[2,j].bar(range(M), A3m)
    
plt.show()
# Out:
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.90657828081895, tolerance: 0.23170569520962964
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.043704000443114, tolerance: 0.23322138240943205
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.38622878894306, tolerance: 0.22989278392622675
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.3649967213255, tolerance: 0.23431356977114648
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.11773978637478, tolerance: 0.2320397203774238
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.001509811405107, tolerance: 0.2323158682717795
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.63510763497432, tolerance: 0.23082781602000038
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.54192796975271, tolerance: 0.23551255101102989
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.5322901495432, tolerance: 0.23228323230558295
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.831771149282893, tolerance: 0.2338446855832144
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.26603432803297, tolerance: 0.23469663593237106
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.31553572651716, tolerance: 0.23654823175787693
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.27050220310623, tolerance: 0.23110890181465693
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.73068150739931, tolerance: 0.23256626174896178
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.419087883956692, tolerance: 0.23094245853722234
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.016115288508146, tolerance: 0.2349582944736014
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.11213342184926, tolerance: 0.23212257425754865
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.65945604775061, tolerance: 0.23390632026443597
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.366675015098714, tolerance: 0.2320712800815728
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.303328745270925, tolerance: 0.23594849161095724
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.519527769315523, tolerance: 0.23366614697505816
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.91049167523643, tolerance: 0.23436820205426417
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.257185471685798, tolerance: 0.23380768943756167
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.516286313043125, tolerance: 0.23218088982486348
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.742031113798134, tolerance: 0.23267420532368258
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.239542377658914, tolerance: 0.23386796431035334
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.266113647279326, tolerance: 0.23318388933927486
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.016661679489765, tolerance: 0.23025560358463867
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.060887616171073, tolerance: 0.23479140683947894
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.974541204411725, tolerance: 0.2358534759295129
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.904063854105345, tolerance: 0.2332997957617487
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.278006747754745, tolerance: 0.23563714337247008
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.20249245032728, tolerance: 0.23280499904572693
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.40655228049003, tolerance: 0.23192897688934033
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.93622734715483, tolerance: 0.23320378664199562
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.068041529472854, tolerance: 0.23263301766420974
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.49723161532954, tolerance: 0.23501834147183745
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.997828269959157, tolerance: 0.2331577810365703
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.296773674016016, tolerance: 0.23091758099770315
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.220278186584434, tolerance: 0.23091735892096854
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.94135520885628, tolerance: 0.23711194651870207
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.874890154242213, tolerance: 0.23188740681990586
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.14446969210037, tolerance: 0.23023300642797026
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.24405677400138, tolerance: 0.2343483927222425
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.935158172659175, tolerance: 0.23341067489978107
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.912394162896383, tolerance: 0.23209973341890286
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.66839088232412, tolerance: 0.23280123958513546
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.436315916905684, tolerance: 0.23509561135494406
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.3832657192624, tolerance: 0.23397582098551795
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.384108158268106, tolerance: 0.23429471305040098
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.440986126675504, tolerance: 0.23160417081691487
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.23755815560397, tolerance: 0.2311316503478711
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.48588357226093, tolerance: 0.23016468060292034
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.245291261125956, tolerance: 0.22983220500791374
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.667126691130235, tolerance: 0.22897580345468768
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.924966464373338, tolerance: 0.23498984948737267
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.64366511038344, tolerance: 0.2376252699508263
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.420160529525845, tolerance: 0.2302865875452678
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36.00406626352779, tolerance: 0.23189297434748785
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.02509407439139, tolerance: 0.23232916293800868
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.968208351611466, tolerance: 0.2308075347612664
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.03459538107739, tolerance: 0.23126828891151813
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.705152987698003, tolerance: 0.23342599042223305
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.91956240886007, tolerance: 0.23063772224496376
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.52617360047295, tolerance: 0.23611742809569605
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.68349153064017, tolerance: 0.23111269451231733
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.37965756480727, tolerance: 0.2308776074811837
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.02763599199844, tolerance: 0.2358697932212097
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.996752070511704, tolerance: 0.23078925630120475
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.157784314485845, tolerance: 0.23254768518741575
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.15470538605259, tolerance: 0.23102577706432126
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.604782314750018, tolerance: 0.2309822561133728
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.99585758156723, tolerance: 0.2333213337960389
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.93555780470968, tolerance: 0.23238609860831452
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.34515963132988, tolerance: 0.2314144702800271
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.13850546033807, tolerance: 0.23445323010690258
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.11760212503137, tolerance: 0.23268705741939277
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.297791183476505, tolerance: 0.23336718070224394
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.733812750864814, tolerance: 0.23321672993144127
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.13970135747017, tolerance: 0.23077052962830977
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.92880042636488, tolerance: 0.2333621676878383
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.404339171301785, tolerance: 0.23625561588218894
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.0462798560817, tolerance: 0.23543158837926786
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.85514548975139, tolerance: 0.2334195695957895
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.10186577915883, tolerance: 0.23317023396969108
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.21416336738924, tolerance: 0.2352310020180021
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.60230865768195, tolerance: 0.23233498741711037
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.2683213054856, tolerance: 0.2370328558435356
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.033132186462154, tolerance: 0.23418991981113238
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.7927428766968, tolerance: 0.23098660929626685
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.15657179752175, tolerance: 0.23229547124580097
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.254110498474773, tolerance: 0.23268447360200786
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.78080560290664, tolerance: 0.23528379816038184
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.21528190227854, tolerance: 0.2330891999184808
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.45468187857906, tolerance: 0.23373325876185733
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.15578153608739, tolerance: 0.23232778893164518
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.950933807992037, tolerance: 0.23173433925231043
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.894882781692633, tolerance: 0.23236318741781242
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.23233790869911, tolerance: 0.23367060971255288
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.869766334019637, tolerance: 0.23013148869364108
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.89094264875869, tolerance: 0.2314485863425373
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.76392323944324, tolerance: 0.23631038977091254
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.622667989115243, tolerance: 0.23256577730316333
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.282856305983135, tolerance: 0.23003649683010358
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.84772689847823, tolerance: 0.23216278310347693
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.628745603230794, tolerance: 0.23408599867910368
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.24985438701728, tolerance: 0.23274109750183766
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.45028772980745, tolerance: 0.23307525265866927
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.72325533256051, tolerance: 0.23284375569534305
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.0527192802079, tolerance: 0.23233573044985856
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.816400012894626, tolerance: 0.23249552265455045
#   model = cd_fast.enet_coordinate_descent(
# c:\users\17175\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.68000362364435, tolerance: 0.23306045984111193
#   model = cd_fast.enet_coordinate_descent(

# %%
plt.rcParams['figure.figsize'] = [8,8]

Atot = np.column_stack((A1m,A2m,A3m)) # Average loadings of three methods
Atot2 = (Atot>0.2) * Atot # threshold
Atot3 = np.column_stack((Atot,Atot2)) # combine both thresholded and not
colors = ('k', 'lime', 'red')
for j in range(3):
    plt.bar(np.arange(Atot.shape[0])*4+j, Atot[:,j], label='A'+str(j+1)+'m', color=colors[j])
    
plt.xlim(0,4*M)
plt.title('Unthresholded')
plt.legend()

plt.figure()
for j in range(3):
    plt.bar(np.arange(Atot2.shape[0])*8+j,Atot[:,j],label='A'+str(j+1)+'m')
    
plt.title('Thresholded')
plt.xlim(0,4*M)
plt.legend()

plt.show()

# %%
n = 200
L = 8
x = np.linspace(0,L,n)
x1 = x[:100]    # Train
x2 = x[100:200] # Test
n1 = len(x1)
n2 = len(x2)
ftrain = np.power(x1,2) # Train parabola x = [0,4]
ftest = np.power(x2,2)  # Test parabola x = [4,8]

phi_i = np.zeros((n1,M))
phi_e = np.zeros((n2,M))

for j in range(M):
    phi_i[:,j] = np.power(x1,j) # interpolation key
    phi_e[:,j] = np.power(x2,j) # extrapolation key
    
Eni = np.zeros(6)
Ene = np.zeros(6)
for jj in range(6): # compute inter/extra-polation scores
    ani = Atot3[:,jj]
    fnai = phi_i @ ani
    Eni[jj] = np.linalg.norm(ftrain-fnai,ord=2)/np.linalg.norm(ftrain,ord=2)
    fnae = phi_e @ ani
    Ene[jj] = np.linalg.norm(ftest-fnae,ord=2)/np.linalg.norm(ftest,ord=2)
    
fig,axs = plt.subplots(2,2)
axs[0,0].bar(range(6),Eni)
axs[0,1].bar(range(6),Ene)
axs[1,0].bar(range(6),Eni)
axs[1,0].set_xlim(-0.5,6.5)
axs[1,0].set_ylim(0,0.01)
axs[1,1].bar(range(6),Ene)
axs[1,1].set_xlim(-0.5,6.5)
axs[1,1].set_ylim(0,0.1)

plt.show()
